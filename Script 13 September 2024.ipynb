-- %% [markdown]
-- # [Task_Management]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [Task_Management]    Script Date: 13/09/2024 13:50:15 ******/
CREATE DATABASE [Task_Management]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'Task_Management', FILENAME = N'C:\Databases\Task_ManagementDB\Task_Management.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'Task_Management_log', FILENAME = N'C:\Databases\Task_ManagementDB\Task_Management_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [Task_Management] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [Task_Management].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [Task_Management] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [Task_Management] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [Task_Management] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [Task_Management] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [Task_Management] SET ARITHABORT OFF 
GO
ALTER DATABASE [Task_Management] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [Task_Management] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [Task_Management] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [Task_Management] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [Task_Management] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [Task_Management] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [Task_Management] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [Task_Management] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [Task_Management] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [Task_Management] SET  DISABLE_BROKER 
GO
ALTER DATABASE [Task_Management] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [Task_Management] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [Task_Management] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [Task_Management] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [Task_Management] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [Task_Management] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [Task_Management] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [Task_Management] SET RECOVERY FULL 
GO
ALTER DATABASE [Task_Management] SET  MULTI_USER 
GO
ALTER DATABASE [Task_Management] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [Task_Management] SET DB_CHAINING OFF 
GO
ALTER DATABASE [Task_Management] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [Task_Management] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [Task_Management] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [Task_Management] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
EXEC sys.sp_db_vardecimal_storage_format N'Task_Management', N'ON'
GO
ALTER DATABASE [Task_Management] SET QUERY_STORE = ON
GO
ALTER DATABASE [Task_Management] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[Person]

-- %%
USE [Task_Management]
GO

-- %%
/****** Object:  Table [dbo].[Person]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Person](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[FName] [nvarchar](50) NULL,
	[LName] [nvarchar](50) NULL,
	[Gender] [char](1) NULL,
	[BDate] [date] NULL,
	[Username] [nvarchar](100) NULL,
	[Password] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[PersonHistory]

-- %%
/****** Object:  Table [dbo].[PersonHistory]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[PersonHistory](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[PersonID] [int] NULL,
	[FName] [nvarchar](50) NULL,
	[LName] [nvarchar](50) NULL,
	[Gender] [char](1) NULL,
	[BDate] [date] NULL,
	[Username] [nvarchar](100) NULL,
	[Password] [nvarchar](100) NULL,
	[ChangedBy] [int] NULL,
	[ChangeDate] [datetime] NULL,
	[ChangeType] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Role]

-- %%
/****** Object:  Table [dbo].[Role]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Role](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[RoleName] [nvarchar](100) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Task]

-- %%
/****** Object:  Table [dbo].[Task]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Task](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskName] [nvarchar](100) NULL,
	[Description] [text] NULL,
	[TaskGroupID] [int] NULL,
	[TaskOrder] [int] NULL,
	[DependancyTaskID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskAssignment]

-- %%
/****** Object:  Table [dbo].[TaskAssignment]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskAssignment](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[PersonID] [int] NULL,
	[TaskInstanceID] [int] NULL,
	[AssignedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskAttachment]

-- %%
/****** Object:  Table [dbo].[TaskAttachment]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskAttachment](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskInstanceID] [int] NULL,
	[FilePath] [nvarchar](max) NULL,
	[UploadedBy] [int] NULL,
	[UploadedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskGroup]

-- %%
/****** Object:  Table [dbo].[TaskGroup]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskGroup](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[GroupName] [nvarchar](50) NULL,
	[TaskListTemplateID] [int] NULL,
	[GroupOrder] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskGroupHistory]

-- %%
/****** Object:  Table [dbo].[TaskGroupHistory]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskGroupHistory](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskGroupID] [int] NULL,
	[GroupName] [nvarchar](50) NULL,
	[TaskListTemplateID] [int] NULL,
	[GroupOrder] [int] NULL,
	[ChangedBy] [int] NULL,
	[ChangedDate] [datetime] NULL,
	[ChangedType] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskGroupInstance]

-- %%
/****** Object:  Table [dbo].[TaskGroupInstance]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskGroupInstance](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskGroupID] [int] NULL,
	[TaskListInstanceID] [int] NULL,
	[AssignedTo] [int] NULL,
	[Status] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskGroupInstancePerson]

-- %%
/****** Object:  Table [dbo].[TaskGroupInstancePerson]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskGroupInstancePerson](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskGroupInstanceID] [int] NULL,
	[PersonID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskHistory]

-- %%
/****** Object:  Table [dbo].[TaskHistory]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskHistory](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskID] [int] NULL,
	[TaskName] [nvarchar](100) NULL,
	[Description] [text] NULL,
	[TaskGroupID] [int] NULL,
	[TaskOrder] [int] NULL,
	[DependancyTaskID] [int] NULL,
	[ChangedBy] [int] NULL,
	[ChangedDate] [datetime] NULL,
	[ChangedType] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY] TEXTIMAGE_ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskInstance]

-- %%
/****** Object:  Table [dbo].[TaskInstance]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskInstance](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskID] [int] NULL,
	[TaskGroupInstanceID] [int] NULL,
	[Status] [nvarchar](50) NULL,
	[TaskCompletionDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskListInstance]

-- %%
/****** Object:  Table [dbo].[TaskListInstance]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskListInstance](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskListTemplateID] [int] NULL,
	[StartDate] [datetime] NULL,
	[AssignedTo] [int] NULL,
	[Status] [nvarchar](50) NULL,
	[DueDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskListInstancePerson]

-- %%
/****** Object:  Table [dbo].[TaskListInstancePerson]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskListInstancePerson](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskListInstanceID] [int] NULL,
	[PersonID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskListInstancePersonRole]

-- %%
/****** Object:  Table [dbo].[TaskListInstancePersonRole]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskListInstancePersonRole](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskListInstanceID] [int] NULL,
	[PersonID] [int] NULL,
	[RoleID] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskListTemplate]

-- %%
/****** Object:  Table [dbo].[TaskListTemplate]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskListTemplate](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TempName] [nvarchar](50) NULL,
	[CreatedBy] [int] NULL,
	[CreatedDate] [datetime] NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaskListTemplateHistory]

-- %%
/****** Object:  Table [dbo].[TaskListTemplateHistory]    Script Date: 13/09/2024 13:50:16 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaskListTemplateHistory](
	[ID] [int] IDENTITY(1,1) NOT NULL,
	[TaskListTemplateID] [int] NULL,
	[TempName] [nvarchar](50) NULL,
	[CreatedBy] [int] NULL,
	[CreatedDate] [datetime] NULL,
	[ChangedBy] [int] NULL,
	[ChangedDate] [datetime] NULL,
	[ChangedType] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[ID] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [FK_Task_Task]

-- %%
ALTER TABLE [dbo].[Task]  WITH CHECK ADD  CONSTRAINT [FK_Task_Task] FOREIGN KEY([DependancyTaskID])
REFERENCES [dbo].[Task] ([ID])
GO
ALTER TABLE [dbo].[Task] CHECK CONSTRAINT [FK_Task_Task]
GO

-- %% [markdown]
-- # [FK_Task_TaskGroup]

-- %%
ALTER TABLE [dbo].[Task]  WITH CHECK ADD  CONSTRAINT [FK_Task_TaskGroup] FOREIGN KEY([TaskGroupID])
REFERENCES [dbo].[TaskGroup] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[Task] CHECK CONSTRAINT [FK_Task_TaskGroup]
GO

-- %% [markdown]
-- # [FK_TaskAssignment_Person]

-- %%
ALTER TABLE [dbo].[TaskAssignment]  WITH CHECK ADD  CONSTRAINT [FK_TaskAssignment_Person] FOREIGN KEY([PersonID])
REFERENCES [dbo].[Person] ([ID])
GO
ALTER TABLE [dbo].[TaskAssignment] CHECK CONSTRAINT [FK_TaskAssignment_Person]
GO

-- %% [markdown]
-- # [FK_TaskAssignment_TaskInstance]

-- %%
ALTER TABLE [dbo].[TaskAssignment]  WITH CHECK ADD  CONSTRAINT [FK_TaskAssignment_TaskInstance] FOREIGN KEY([TaskInstanceID])
REFERENCES [dbo].[TaskInstance] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskAssignment] CHECK CONSTRAINT [FK_TaskAssignment_TaskInstance]
GO

-- %% [markdown]
-- # [FK_TaskAttachment_Person]

-- %%
ALTER TABLE [dbo].[TaskAttachment]  WITH CHECK ADD  CONSTRAINT [FK_TaskAttachment_Person] FOREIGN KEY([UploadedBy])
REFERENCES [dbo].[Person] ([ID])
GO
ALTER TABLE [dbo].[TaskAttachment] CHECK CONSTRAINT [FK_TaskAttachment_Person]
GO

-- %% [markdown]
-- # [FK_TaskAttachment_TaskInstance]

-- %%
ALTER TABLE [dbo].[TaskAttachment]  WITH CHECK ADD  CONSTRAINT [FK_TaskAttachment_TaskInstance] FOREIGN KEY([TaskInstanceID])
REFERENCES [dbo].[TaskInstance] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskAttachment] CHECK CONSTRAINT [FK_TaskAttachment_TaskInstance]
GO

-- %% [markdown]
-- # [FK_TaskGroup_TaskListTemplate]

-- %%
ALTER TABLE [dbo].[TaskGroup]  WITH CHECK ADD  CONSTRAINT [FK_TaskGroup_TaskListTemplate] FOREIGN KEY([TaskListTemplateID])
REFERENCES [dbo].[TaskListTemplate] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskGroup] CHECK CONSTRAINT [FK_TaskGroup_TaskListTemplate]
GO

-- %% [markdown]
-- # [FK_TaskGroupInstance_Person]

-- %%
ALTER TABLE [dbo].[TaskGroupInstance]  WITH CHECK ADD  CONSTRAINT [FK_TaskGroupInstance_Person] FOREIGN KEY([AssignedTo])
REFERENCES [dbo].[Person] ([ID])
GO
ALTER TABLE [dbo].[TaskGroupInstance] CHECK CONSTRAINT [FK_TaskGroupInstance_Person]
GO

-- %% [markdown]
-- # [FK_TaskGroupInstance_TaskGroup]

-- %%
ALTER TABLE [dbo].[TaskGroupInstance]  WITH CHECK ADD  CONSTRAINT [FK_TaskGroupInstance_TaskGroup] FOREIGN KEY([TaskGroupID])
REFERENCES [dbo].[TaskGroup] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskGroupInstance] CHECK CONSTRAINT [FK_TaskGroupInstance_TaskGroup]
GO

-- %% [markdown]
-- # [FK_TaskGroupInstance_TaskListInstance]

-- %%
ALTER TABLE [dbo].[TaskGroupInstance]  WITH CHECK ADD  CONSTRAINT [FK_TaskGroupInstance_TaskListInstance] FOREIGN KEY([TaskListInstanceID])
REFERENCES [dbo].[TaskListInstance] ([ID])
GO
ALTER TABLE [dbo].[TaskGroupInstance] CHECK CONSTRAINT [FK_TaskGroupInstance_TaskListInstance]
GO

-- %% [markdown]
-- # [FK_TaskGroupInstancePerson_Person]

-- %%
ALTER TABLE [dbo].[TaskGroupInstancePerson]  WITH CHECK ADD  CONSTRAINT [FK_TaskGroupInstancePerson_Person] FOREIGN KEY([PersonID])
REFERENCES [dbo].[Person] ([ID])
GO
ALTER TABLE [dbo].[TaskGroupInstancePerson] CHECK CONSTRAINT [FK_TaskGroupInstancePerson_Person]
GO

-- %% [markdown]
-- # [FK_TaskGroupInstancePerson_TaskGroupInstance]

-- %%
ALTER TABLE [dbo].[TaskGroupInstancePerson]  WITH CHECK ADD  CONSTRAINT [FK_TaskGroupInstancePerson_TaskGroupInstance] FOREIGN KEY([TaskGroupInstanceID])
REFERENCES [dbo].[TaskGroupInstance] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskGroupInstancePerson] CHECK CONSTRAINT [FK_TaskGroupInstancePerson_TaskGroupInstance]
GO

-- %% [markdown]
-- # [FK_TaskInstance_Task]

-- %%
ALTER TABLE [dbo].[TaskInstance]  WITH CHECK ADD  CONSTRAINT [FK_TaskInstance_Task] FOREIGN KEY([TaskID])
REFERENCES [dbo].[Task] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskInstance] CHECK CONSTRAINT [FK_TaskInstance_Task]
GO

-- %% [markdown]
-- # [FK_TaskInstance_TaskGroupInstance]

-- %%
ALTER TABLE [dbo].[TaskInstance]  WITH CHECK ADD  CONSTRAINT [FK_TaskInstance_TaskGroupInstance] FOREIGN KEY([TaskGroupInstanceID])
REFERENCES [dbo].[TaskGroupInstance] ([ID])
GO
ALTER TABLE [dbo].[TaskInstance] CHECK CONSTRAINT [FK_TaskInstance_TaskGroupInstance]
GO

-- %% [markdown]
-- # [FK_TaskListInstance_Person]

-- %%
ALTER TABLE [dbo].[TaskListInstance]  WITH CHECK ADD  CONSTRAINT [FK_TaskListInstance_Person] FOREIGN KEY([AssignedTo])
REFERENCES [dbo].[Person] ([ID])
GO
ALTER TABLE [dbo].[TaskListInstance] CHECK CONSTRAINT [FK_TaskListInstance_Person]
GO

-- %% [markdown]
-- # [FK_TaskListInstance_TaskListTemplate]

-- %%
ALTER TABLE [dbo].[TaskListInstance]  WITH CHECK ADD  CONSTRAINT [FK_TaskListInstance_TaskListTemplate] FOREIGN KEY([TaskListTemplateID])
REFERENCES [dbo].[TaskListTemplate] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskListInstance] CHECK CONSTRAINT [FK_TaskListInstance_TaskListTemplate]
GO

-- %% [markdown]
-- # [FK_TaskListInstancePerson_Person]

-- %%
ALTER TABLE [dbo].[TaskListInstancePerson]  WITH CHECK ADD  CONSTRAINT [FK_TaskListInstancePerson_Person] FOREIGN KEY([PersonID])
REFERENCES [dbo].[Person] ([ID])
GO
ALTER TABLE [dbo].[TaskListInstancePerson] CHECK CONSTRAINT [FK_TaskListInstancePerson_Person]
GO

-- %% [markdown]
-- # [FK_TaskListInstancePerson_TaskListInstance]

-- %%
ALTER TABLE [dbo].[TaskListInstancePerson]  WITH CHECK ADD  CONSTRAINT [FK_TaskListInstancePerson_TaskListInstance] FOREIGN KEY([TaskListInstanceID])
REFERENCES [dbo].[TaskListInstance] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskListInstancePerson] CHECK CONSTRAINT [FK_TaskListInstancePerson_TaskListInstance]
GO

-- %% [markdown]
-- # [FK_TaskListInstancePersonRole_Person]

-- %%
ALTER TABLE [dbo].[TaskListInstancePersonRole]  WITH CHECK ADD  CONSTRAINT [FK_TaskListInstancePersonRole_Person] FOREIGN KEY([PersonID])
REFERENCES [dbo].[Person] ([ID])
GO
ALTER TABLE [dbo].[TaskListInstancePersonRole] CHECK CONSTRAINT [FK_TaskListInstancePersonRole_Person]
GO

-- %% [markdown]
-- # [FK_TaskListInstancePersonRole_Role]

-- %%
ALTER TABLE [dbo].[TaskListInstancePersonRole]  WITH CHECK ADD  CONSTRAINT [FK_TaskListInstancePersonRole_Role] FOREIGN KEY([RoleID])
REFERENCES [dbo].[Role] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskListInstancePersonRole] CHECK CONSTRAINT [FK_TaskListInstancePersonRole_Role]
GO

-- %% [markdown]
-- # [FK_TaskListInstancePersonRole_TaskListInstance]

-- %%
ALTER TABLE [dbo].[TaskListInstancePersonRole]  WITH CHECK ADD  CONSTRAINT [FK_TaskListInstancePersonRole_TaskListInstance] FOREIGN KEY([TaskListInstanceID])
REFERENCES [dbo].[TaskListInstance] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskListInstancePersonRole] CHECK CONSTRAINT [FK_TaskListInstancePersonRole_TaskListInstance]
GO

-- %% [markdown]
-- # [FK_TaskListTemplate_Person]

-- %%
ALTER TABLE [dbo].[TaskListTemplate]  WITH CHECK ADD  CONSTRAINT [FK_TaskListTemplate_Person] FOREIGN KEY([CreatedBy])
REFERENCES [dbo].[Person] ([ID])
ON UPDATE CASCADE
GO
ALTER TABLE [dbo].[TaskListTemplate] CHECK CONSTRAINT [FK_TaskListTemplate_Person]
GO

-- %% [markdown]
-- # [Task_Management]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [Task_Management] SET  READ_WRITE 
GO
